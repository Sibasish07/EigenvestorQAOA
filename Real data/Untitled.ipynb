# %%
# !pip install pandas_datareader
# !pip install yfinance
# !pip install statsmodels
# !pip install getFamaFrenchFactors
# Out:
# ...
#      |████████████████████████████████| 109 kB 1.4 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
from pandas_datareader import data as web
import getFamaFrenchFactors as gff

tickers = ['AAPL', 'AMZN', 'GOOG', 'INTC', 'META', 'NFLX', 'SBUX', 'TSLA']



# def func_yearly_returns(ticker):
#     stock_data = yf.download(ticker, start="2022-01-15", end="2023-01-15")
#     #stock_data = pd.read_csv('AAPL.csv')
#     stock_prices = stock_data['Adj Close']
#     #stock_data['date'] = pd.to_datetime(stock_data['Date'])
#     stock_prices = stock_prices.resample("1M").last()
#     returns = stock_prices.pct_change()
#     returns = returns.dropna()
#     returns.name = "Asset"

#     ff3_monthly = pd.DataFrame(gff.famaFrench3Factor(frequency='m'))
#     ff3_monthly.rename(columns={"date_ff_factors": 'Date'}, inplace=True)
#     ff3_monthly.set_index('Date', inplace=True)
#     ff3data = pd.concat(returns, ff3_monthly)
#     #ff_data = ff3_monthly.merge(returns, on='Date')
#     rf = ff_data['RF'].mean()
#     market_premium = ff_data['Mkt-RF'].mean()

#     X = ff_data['Mkt-RF']
#     ff_data['Asset-RF'] = ff_data['Asset'] - ff_data['RF']
#     y = ff_data['Asset-RF']
#     c = sm.add_constant(X)
#     capm_model = sm.OLS(y, c)
#     result = capm_model.fit()
#     print(result.summary())
#     intercept, beta = result.params

#     expected_return = rf + beta*market_premium
#     print("Expected monthly returns: " + str(expected_return))
#     yearly_return = expected_return * 12
#     print("Expected yearly returns: " + str(yearly_return))
    
 
# expected_returns = []
# yearly_returns = []

# for ticker in tickers:
#     func_yearly_returns(ticker)
    # expected_returns.append(temp1)
    # yearly_returns.append(temp2)
    
# print(expected_returns)
# #stock_data = pd.read_csv('AAPL.csv')print(yearly_returns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/j5/85hj0_110cbbkrm4wsqq8qkm0000gn/T/ipykernel_17272/1582818207.py in <module>
#       5 import getFamaFrenchFactors as gff
#       6
# ----> 7 netflix = web.get_data_yahoo('NFLX',
#       8                             start = "2009-01-01",
#       9                             end = "2018-03-01")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/data.py in get_data_yahoo(*args, **kwargs)
#      78
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#      81
#      82
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# ...

# %%
daily_simple_returns = data.pct_change()
daily_simple_returns.head()
