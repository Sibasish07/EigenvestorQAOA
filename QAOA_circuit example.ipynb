# %%
import main
import cirq
import math
from cirq.contrib.svg import SVGCircuit
import sympy
import numpy as np
import matplotlib.pyplot as plt

# %%
#Example of QAOA circuit with arbitrary parameters
beta=[1,1]
gamma=[1,1] #beta and gamma are arrays of length p=circuit depth

# %%
#Show QAOA circuit with soft constraints
SVGCircuit(main.circuit_builder_p(beta,gamma))

# %%
#Show QAOA circuit with soft constraints
SVGCircuit(main.circuit_builder_p_hard(beta,gamma))
