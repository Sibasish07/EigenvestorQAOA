# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Q_min_soft1 = np.loadtxt('Q_min_p1_iter10_Nce10_f02_soft.csv', delimiter=',')
#Q_mean_soft1 = np.loadtxt('Q_mean_p1_iter10_Nce10_f02_soft.csv', delimiter=',')
Q_min_soft1 = np.loadtxt('Q_min_p2_iter10_Nce10_f02_soft.csv', delimiter=',')
Q_mean_soft1 = np.loadtxt('Q_mean_p2_iter10_Nce10_f02_soft.csv', delimiter=',')
Q_min_soft2 = np.loadtxt('Q_min_p2_iter10_Nce15_f02_soft.csv', delimiter=',')
Q_mean_soft2 = np.loadtxt('Q_mean_p2_iter10_Nce15_f02_soft.csv', delimiter=',')
Q_min_soft3 = np.loadtxt('Q_min_p2_iter10_Nce20_f02_soft.csv', delimiter=',')
Q_mean_soft3 = np.loadtxt('Q_mean_p2_iter10_Nce20_f02_soft.csv', delimiter=',')
Q_min_hard1 = np.loadtxt('Q_min_p2_iter10_Nce10_f02_hard.csv', delimiter=',')
Q_mean_hard1 = np.loadtxt('Q_mean_p2_iter10_Nce10_f02_hard.csv', delimiter=',')
Q_min_hard2 = np.loadtxt('Q_min_p2_iter10_Nce15_f02_hard.csv', delimiter=',')
Q_mean_hard2 = np.loadtxt('Q_mean_p2_iter10_Nce15_f02_hard.csv', delimiter=',')
Q_min_hard3 = np.loadtxt('Q_min_p2_iter10_Nce20_f02_hard.csv', delimiter=',')
Q_mean_hard3 = np.loadtxt('Q_mean_p2_iter10_Nce20_f02_hard.csv', delimiter=',')
# Q_min_soft3 = np.loadtxt('Q_min_p3_iter10_Nce10_f02_soft.csv', delimiter=',')
# Q_mean_soft3 = np.loadtxt('Q_mean_p3_iter10_Nce10_f02_soft.csv', delimiter=',')
# Q_min_soft4 = np.loadtxt('Q_min_p4_iter10_Nce10_f02_soft.csv', delimiter=',')
# Q_mean_soft4 = np.loadtxt('Q_mean_p4_iter10_Nce10_f02_soft.csv', delimiter=',')
# Q_min_hard1 = np.loadtxt('Q_min_p1_iter10_Nce10_f02_hard.csv', delimiter=',')
# Q_mean_hard1 = np.loadtxt('Q_mean_p1_iter10_Nce10_f02_hard.csv', delimiter=',')
# Q_min_hard2 = np.loadtxt('Q_min_p2_iter10_Nce10_f02_hard.csv', delimiter=',')
# Q_mean_hard2 = np.loadtxt('Q_mean_p2_iter10_Nce10_f02_hard.csv', delimiter=',')
# Q_min_hard3 = np.loadtxt('Q_min_p3_iter10_Nce10_f02_hard.csv', delimiter=',')
# Q_mean_hard3 = np.loadtxt('Q_mean_p3_iter10_Nce10_f02_hard.csv', delimiter=',')
# Q_min_hard4 = np.loadtxt('Q_min_p4_iter10_Nce10_f02_hard.csv', delimiter=',')
# Q_mean_hard4 = np.loadtxt('Q_mean_p4_iter10_Nce10_f02_hard.csv', delimiter=',')

# %%
p1sm=[np.mean(Q_min_soft1[:,0]),np.mean(Q_min_soft2[:,0]),np.mean(Q_min_soft3[:,0])]#,np.mean(Q_min_soft4[:,0])]
p2sm=[np.mean(Q_min_soft1[:,1]),np.mean(Q_min_soft2[:,1]),np.mean(Q_min_soft3[:,1])]#,np.mean(Q_min_soft4[:,1])]
p3sm=[np.mean(Q_min_soft1[:,2]),np.mean(Q_min_soft2[:,2]),np.mean(Q_min_soft3[:,2])]#,np.mean(Q_min_soft4[:,2])]
p1sM=[np.mean(Q_mean_soft1[:,0]),np.mean(Q_mean_soft2[:,0]),np.mean(Q_mean_soft3[:,0])]#,np.mean(Q_mean_soft4[:,0])]
p2sM=[np.mean(Q_mean_soft1[:,1]),np.mean(Q_mean_soft2[:,1]),np.mean(Q_mean_soft3[:,1])]#,np.mean(Q_mean_soft4[:,1])]
p3sM=[np.mean(Q_mean_soft1[:,2]),np.mean(Q_mean_soft2[:,2]),np.mean(Q_mean_soft3[:,2])]#,np.mean(Q_mean_soft4[:,2])]
p1hm=[np.mean(Q_min_hard1[:,0]),np.mean(Q_min_hard2[:,0]),np.mean(Q_min_hard3[:,0])]#,np.mean(Q_min_hard4[:,0])]
p2hm=[np.mean(Q_min_hard1[:,1]),np.mean(Q_min_hard2[:,1]),np.mean(Q_min_hard3[:,1])]#,np.mean(Q_min_hard4[:,1])]
p3hm=[np.mean(Q_min_hard1[:,2]),np.mean(Q_min_hard2[:,2]),np.mean(Q_min_hard3[:,2])]#,np.mean(Q_min_hard4[:,2])]
p1hM=[np.mean(Q_mean_hard1[:,0]),np.mean(Q_mean_hard2[:,0]),np.mean(Q_mean_hard3[:,0])]#,np.mean(Q_mean_hard4[:,0])]
p2hM=[np.mean(Q_mean_hard1[:,1]),np.mean(Q_mean_hard2[:,1]),np.mean(Q_mean_hard3[:,1])]#,np.mean(Q_mean_hard4[:,1])]
p3hM=[np.mean(Q_mean_hard1[:,2]),np.mean(Q_mean_hard2[:,2]),np.mean(Q_mean_hard3[:,2])]#,np.mean(Q_mean_hard4[:,2])]
#xj=range(1,4)
xj=[10,15,20]

# %%
plt.plot(xj,p1sm,"-ob",label="Min Soft")
plt.plot(xj,p1sM,"-or",label="Mean Soft")
plt.plot(xj,p1hm,"-og",label="Min Hard")
plt.plot(xj,p1hM,"-.m",label="Mean Hard")
plt.grid()
plt.legend()
plt.xlabel("NCE")
plt.ylabel("Probability Treshold")
# Out:
# Text(0, 0.5, 'Probability Treshold')

# %%
plt.plot(xj,p2sm,"-ob",label="Min Soft")
plt.plot(xj,p2sM,"-or",label="Mean Soft")
plt.plot(xj,p2hm,"-og",label="Min Hard")
plt.plot(xj,p2hM,"-om",label="Mean Hard")
plt.grid()
plt.legend()
plt.xlabel("NCE")
plt.ylabel("Probability success")
# Out:
# Text(0, 0.5, 'Probability success')

# %%
#plt.plot(xj,p3sm,"-ob",label="Min Soft")
#plt.plot(xj,p3sM,"-or",label="Mean Soft")
plt.plot(xj,p3hm,"-og",label="Min Hard")
plt.plot(xj,p3hM,"-om",label="Mean Hard")
plt.grid()
plt.legend()
plt.xlabel("NCE")
plt.ylabel("Mean Energy")
# Out:
# Text(0, 0.5, 'Mean Energy')

# %%
Q_mean_hard2
# Out:
# array([[1.0000000e+00, 9.9500000e-01, 1.8853853e-04],
#        [1.0000000e+00, 8.2900000e-01, 2.0820623e-04],
#        [1.0000000e+00, 1.0000000e-03, 2.1266699e-04],
#        [1.0000000e+00, 6.7300000e-01, 2.3691401e-04],
#        [1.0000000e+00, 9.0500000e-01, 1.9845737e-04],
#        [1.0000000e+00, 9.9200000e-01, 1.8954452e-04],
#        [1.0000000e+00, 9.6900000e-01, 1.9241915e-04],
#        [1.0000000e+00, 5.4000000e-01, 2.5961292e-04],
#        [1.0000000e+00, 8.7400000e-01, 1.9794817e-04],
#        [1.0000000e+00, 8.6000000e-01, 2.1022760e-04]])

# %%
x1_sm = np.sort(Q_min_soft1[:,2])
y1_sm = np.sort(Q_min_soft1[:,0])
x2_sM = np.sort(Q_mean_soft1[:,2])
y2_sM = np.sort(Q_mean_soft1[:,0])
plt.plot(x1_sm, y1_sm, label="Min Soft, NCE=10")
plt.plot(x2_sM, y2_sM, label="Mean Soft, NCE=10")
plt.grid()
plt.legend()
plt.xlabel("Cost Function C(s)")
plt.ylabel("Probability")
# Out:
# Text(0, 0.5, 'Probability')
